# %%
### ✅ 1. 필요한 라이브러리 및 모듈 불러오기
import os
from process_video import extract_frames
from predict_deepfake_model import process_all_frames
import json
from IPython.display import display, Image

# %%
### ✅ 2. 영상 → 프레임 추출 셀
def extract_video_frames(video_path, output_folder="frames", fps=1):
    print(f"🎬 영상에서 프레임 추출 중...")
    extract_frames(video_path, output_folder, fps)
    print(f"✅ 프레임 추출 완료: {output_folder}")

# 사용 예시
video_path = "video/video.mp4"  # 분석할 영상 경로
frames_folder = "frames"               # 프레임 저장 폴더
extract_video_frames(video_path, frames_folder, fps=30)
# Out:
# 🎬 영상에서 프레임 추출 중...
# 🎬 FPS: 30.0, Frame Interval: 1, Total Frames: 282
# 🖼️ 저장됨: frames\frame_0000.jpg
# 🖼️ 저장됨: frames\frame_0001.jpg
# 🖼️ 저장됨: frames\frame_0002.jpg
# 🖼️ 저장됨: frames\frame_0003.jpg
# 🖼️ 저장됨: frames\frame_0004.jpg
# 🖼️ 저장됨: frames\frame_0005.jpg
# 🖼️ 저장됨: frames\frame_0006.jpg
# 🖼️ 저장됨: frames\frame_0007.jpg
# 🖼️ 저장됨: frames\frame_0008.jpg
# 🖼️ 저장됨: frames\frame_0009.jpg
# 🖼️ 저장됨: frames\frame_0010.jpg
# 🖼️ 저장됨: frames\frame_0011.jpg
# 🖼️ 저장됨: frames\frame_0012.jpg
# 🖼️ 저장됨: frames\frame_0013.jpg
# 🖼️ 저장됨: frames\frame_0014.jpg
# 🖼️ 저장됨: frames\frame_0015.jpg
# 🖼️ 저장됨: frames\frame_0016.jpg
# 🖼️ 저장됨: frames\frame_0017.jpg
# 🖼️ 저장됨: frames\frame_0018.jpg
# 🖼️ 저장됨: frames\frame_0019.jpg
# 🖼️ 저장됨: frames\frame_0020.jpg
# 🖼️ 저장됨: frames\frame_0021.jpg
# 🖼️ 저장됨: frames\frame_0022.jpg
# 🖼️ 저장됨: frames\frame_0023.jpg
# 🖼️ 저장됨: frames\frame_0024.jpg
# 🖼️ 저장됨: frames\frame_0025.jpg
# 🖼️ 저장됨: frames\frame_0026.jpg
# 🖼️ 저장됨: frames\frame_0027.jpg
# 🖼️ 저장됨: frames\frame_0028.jpg
# 🖼️ 저장됨: frames\frame_0029.jpg
# 🖼️ 저장됨: frames\frame_0030.jpg
# 🖼️ 저장됨: frames\frame_0031.jpg
# 🖼️ 저장됨: frames\frame_0032.jpg
# 🖼️ 저장됨: frames\frame_0033.jpg
# 🖼️ 저장됨: frames\frame_0034.jpg
# 🖼️ 저장됨: frames\frame_0035.jpg
# 🖼️ 저장됨: frames\frame_0036.jpg
# 🖼️ 저장됨: frames\frame_0037.jpg
# 🖼️ 저장됨: frames\frame_0038.jpg
# 🖼️ 저장됨: frames\frame_0039.jpg
# 🖼️ 저장됨: frames\frame_0040.jpg
# 🖼️ 저장됨: frames\frame_0041.jpg
# 🖼️ 저장됨: frames\frame_0042.jpg
# 🖼️ 저장됨: frames\frame_0043.jpg
# 🖼️ 저장됨: frames\frame_0044.jpg
# 🖼️ 저장됨: frames\frame_0045.jpg
# 🖼️ 저장됨: frames\frame_0046.jpg
# 🖼️ 저장됨: frames\frame_0047.jpg
# 🖼️ 저장됨: frames\frame_0048.jpg
# 🖼️ 저장됨: frames\frame_0049.jpg
# 🖼️ 저장됨: frames\frame_0050.jpg
# 🖼️ 저장됨: frames\frame_0051.jpg
# 🖼️ 저장됨: frames\frame_0052.jpg
# 🖼️ 저장됨: frames\frame_0053.jpg
# 🖼️ 저장됨: frames\frame_0054.jpg
# 🖼️ 저장됨: frames\frame_0055.jpg
# 🖼️ 저장됨: frames\frame_0056.jpg
# 🖼️ 저장됨: frames\frame_0057.jpg
# 🖼️ 저장됨: frames\frame_0058.jpg
# 🖼️ 저장됨: frames\frame_0059.jpg
# 🖼️ 저장됨: frames\frame_0060.jpg
# 🖼️ 저장됨: frames\frame_0061.jpg
# 🖼️ 저장됨: frames\frame_0062.jpg
# 🖼️ 저장됨: frames\frame_0063.jpg
# 🖼️ 저장됨: frames\frame_0064.jpg
# 🖼️ 저장됨: frames\frame_0065.jpg
# 🖼️ 저장됨: frames\frame_0066.jpg
# 🖼️ 저장됨: frames\frame_0067.jpg
# 🖼️ 저장됨: frames\frame_0068.jpg
# 🖼️ 저장됨: frames\frame_0069.jpg
# 🖼️ 저장됨: frames\frame_0070.jpg
# 🖼️ 저장됨: frames\frame_0071.jpg
# 🖼️ 저장됨: frames\frame_0072.jpg
# 🖼️ 저장됨: frames\frame_0073.jpg
# 🖼️ 저장됨: frames\frame_0074.jpg
# 🖼️ 저장됨: frames\frame_0075.jpg
# 🖼️ 저장됨: frames\frame_0076.jpg
# 🖼️ 저장됨: frames\frame_0077.jpg
# 🖼️ 저장됨: frames\frame_0078.jpg
# 🖼️ 저장됨: frames\frame_0079.jpg
# 🖼️ 저장됨: frames\frame_0080.jpg
# 🖼️ 저장됨: frames\frame_0081.jpg
# 🖼️ 저장됨: frames\frame_0082.jpg
# 🖼️ 저장됨: frames\frame_0083.jpg
# 🖼️ 저장됨: frames\frame_0084.jpg
# 🖼️ 저장됨: frames\frame_0085.jpg
# 🖼️ 저장됨: frames\frame_0086.jpg
# 🖼️ 저장됨: frames\frame_0087.jpg
# 🖼️ 저장됨: frames\frame_0088.jpg
# 🖼️ 저장됨: frames\frame_0089.jpg
# 🖼️ 저장됨: frames\frame_0090.jpg
# 🖼️ 저장됨: frames\frame_0091.jpg
# 🖼️ 저장됨: frames\frame_0092.jpg
# 🖼️ 저장됨: frames\frame_0093.jpg
# 🖼️ 저장됨: frames\frame_0094.jpg
# 🖼️ 저장됨: frames\frame_0095.jpg
# 🖼️ 저장됨: frames\frame_0096.jpg
# 🖼️ 저장됨: frames\frame_0097.jpg
# 🖼️ 저장됨: frames\frame_0098.jpg
# 🖼️ 저장됨: frames\frame_0099.jpg
# 🖼️ 저장됨: frames\frame_0100.jpg
# 🖼️ 저장됨: frames\frame_0101.jpg
# 🖼️ 저장됨: frames\frame_0102.jpg
# 🖼️ 저장됨: frames\frame_0103.jpg
# 🖼️ 저장됨: frames\frame_0104.jpg
# 🖼️ 저장됨: frames\frame_0105.jpg
# 🖼️ 저장됨: frames\frame_0106.jpg
# 🖼️ 저장됨: frames\frame_0107.jpg
# 🖼️ 저장됨: frames\frame_0108.jpg
# 🖼️ 저장됨: frames\frame_0109.jpg
# 🖼️ 저장됨: frames\frame_0110.jpg
# 🖼️ 저장됨: frames\frame_0111.jpg
# 🖼️ 저장됨: frames\frame_0112.jpg
# 🖼️ 저장됨: frames\frame_0113.jpg
# 🖼️ 저장됨: frames\frame_0114.jpg
# 🖼️ 저장됨: frames\frame_0115.jpg
# 🖼️ 저장됨: frames\frame_0116.jpg
# 🖼️ 저장됨: frames\frame_0117.jpg
# 🖼️ 저장됨: frames\frame_0118.jpg
# 🖼️ 저장됨: frames\frame_0119.jpg
# 🖼️ 저장됨: frames\frame_0120.jpg
# 🖼️ 저장됨: frames\frame_0121.jpg
# 🖼️ 저장됨: frames\frame_0122.jpg
# 🖼️ 저장됨: frames\frame_0123.jpg
# 🖼️ 저장됨: frames\frame_0124.jpg
# 🖼️ 저장됨: frames\frame_0125.jpg
# 🖼️ 저장됨: frames\frame_0126.jpg
# 🖼️ 저장됨: frames\frame_0127.jpg
# 🖼️ 저장됨: frames\frame_0128.jpg
# 🖼️ 저장됨: frames\frame_0129.jpg
# 🖼️ 저장됨: frames\frame_0130.jpg
# 🖼️ 저장됨: frames\frame_0131.jpg
# 🖼️ 저장됨: frames\frame_0132.jpg
# 🖼️ 저장됨: frames\frame_0133.jpg
# 🖼️ 저장됨: frames\frame_0134.jpg
# 🖼️ 저장됨: frames\frame_0135.jpg
# 🖼️ 저장됨: frames\frame_0136.jpg
# 🖼️ 저장됨: frames\frame_0137.jpg
# 🖼️ 저장됨: frames\frame_0138.jpg
# 🖼️ 저장됨: frames\frame_0139.jpg
# 🖼️ 저장됨: frames\frame_0140.jpg
# 🖼️ 저장됨: frames\frame_0141.jpg
# 🖼️ 저장됨: frames\frame_0142.jpg
# 🖼️ 저장됨: frames\frame_0143.jpg
# 🖼️ 저장됨: frames\frame_0144.jpg
# 🖼️ 저장됨: frames\frame_0145.jpg
# 🖼️ 저장됨: frames\frame_0146.jpg
# 🖼️ 저장됨: frames\frame_0147.jpg
# 🖼️ 저장됨: frames\frame_0148.jpg
# 🖼️ 저장됨: frames\frame_0149.jpg
# 🖼️ 저장됨: frames\frame_0150.jpg
# 🖼️ 저장됨: frames\frame_0151.jpg
# 🖼️ 저장됨: frames\frame_0152.jpg
# 🖼️ 저장됨: frames\frame_0153.jpg
# 🖼️ 저장됨: frames\frame_0154.jpg
# 🖼️ 저장됨: frames\frame_0155.jpg
# 🖼️ 저장됨: frames\frame_0156.jpg
# 🖼️ 저장됨: frames\frame_0157.jpg
# 🖼️ 저장됨: frames\frame_0158.jpg
# 🖼️ 저장됨: frames\frame_0159.jpg
# 🖼️ 저장됨: frames\frame_0160.jpg
# 🖼️ 저장됨: frames\frame_0161.jpg
# 🖼️ 저장됨: frames\frame_0162.jpg
# 🖼️ 저장됨: frames\frame_0163.jpg
# 🖼️ 저장됨: frames\frame_0164.jpg
# 🖼️ 저장됨: frames\frame_0165.jpg
# 🖼️ 저장됨: frames\frame_0166.jpg
# 🖼️ 저장됨: frames\frame_0167.jpg
# 🖼️ 저장됨: frames\frame_0168.jpg
# 🖼️ 저장됨: frames\frame_0169.jpg
# 🖼️ 저장됨: frames\frame_0170.jpg
# 🖼️ 저장됨: frames\frame_0171.jpg
# 🖼️ 저장됨: frames\frame_0172.jpg
# 🖼️ 저장됨: frames\frame_0173.jpg
# 🖼️ 저장됨: frames\frame_0174.jpg
# 🖼️ 저장됨: frames\frame_0175.jpg
# 🖼️ 저장됨: frames\frame_0176.jpg
# 🖼️ 저장됨: frames\frame_0177.jpg
# 🖼️ 저장됨: frames\frame_0178.jpg
# 🖼️ 저장됨: frames\frame_0179.jpg
# 🖼️ 저장됨: frames\frame_0180.jpg
# 🖼️ 저장됨: frames\frame_0181.jpg
# 🖼️ 저장됨: frames\frame_0182.jpg
# 🖼️ 저장됨: frames\frame_0183.jpg
# 🖼️ 저장됨: frames\frame_0184.jpg
# 🖼️ 저장됨: frames\frame_0185.jpg
# 🖼️ 저장됨: frames\frame_0186.jpg
# 🖼️ 저장됨: frames\frame_0187.jpg
# 🖼️ 저장됨: frames\frame_0188.jpg
# 🖼️ 저장됨: frames\frame_0189.jpg
# 🖼️ 저장됨: frames\frame_0190.jpg
# 🖼️ 저장됨: frames\frame_0191.jpg
# 🖼️ 저장됨: frames\frame_0192.jpg
# 🖼️ 저장됨: frames\frame_0193.jpg
# 🖼️ 저장됨: frames\frame_0194.jpg
# 🖼️ 저장됨: frames\frame_0195.jpg
# 🖼️ 저장됨: frames\frame_0196.jpg
# 🖼️ 저장됨: frames\frame_0197.jpg
# 🖼️ 저장됨: frames\frame_0198.jpg
# 🖼️ 저장됨: frames\frame_0199.jpg
# 🖼️ 저장됨: frames\frame_0200.jpg
# 🖼️ 저장됨: frames\frame_0201.jpg
# 🖼️ 저장됨: frames\frame_0202.jpg
# 🖼️ 저장됨: frames\frame_0203.jpg
# 🖼️ 저장됨: frames\frame_0204.jpg
# 🖼️ 저장됨: frames\frame_0205.jpg
# 🖼️ 저장됨: frames\frame_0206.jpg
# 🖼️ 저장됨: frames\frame_0207.jpg
# 🖼️ 저장됨: frames\frame_0208.jpg
# 🖼️ 저장됨: frames\frame_0209.jpg
# 🖼️ 저장됨: frames\frame_0210.jpg
# 🖼️ 저장됨: frames\frame_0211.jpg
# 🖼️ 저장됨: frames\frame_0212.jpg
# 🖼️ 저장됨: frames\frame_0213.jpg
# 🖼️ 저장됨: frames\frame_0214.jpg
# 🖼️ 저장됨: frames\frame_0215.jpg
# 🖼️ 저장됨: frames\frame_0216.jpg
# 🖼️ 저장됨: frames\frame_0217.jpg
# 🖼️ 저장됨: frames\frame_0218.jpg
# 🖼️ 저장됨: frames\frame_0219.jpg
# 🖼️ 저장됨: frames\frame_0220.jpg
# 🖼️ 저장됨: frames\frame_0221.jpg
# 🖼️ 저장됨: frames\frame_0222.jpg
# 🖼️ 저장됨: frames\frame_0223.jpg
# 🖼️ 저장됨: frames\frame_0224.jpg
# 🖼️ 저장됨: frames\frame_0225.jpg
# 🖼️ 저장됨: frames\frame_0226.jpg
# 🖼️ 저장됨: frames\frame_0227.jpg
# 🖼️ 저장됨: frames\frame_0228.jpg
# 🖼️ 저장됨: frames\frame_0229.jpg
# 🖼️ 저장됨: frames\frame_0230.jpg
# 🖼️ 저장됨: frames\frame_0231.jpg
# 🖼️ 저장됨: frames\frame_0232.jpg
# 🖼️ 저장됨: frames\frame_0233.jpg
# 🖼️ 저장됨: frames\frame_0234.jpg
# 🖼️ 저장됨: frames\frame_0235.jpg
# 🖼️ 저장됨: frames\frame_0236.jpg
# 🖼️ 저장됨: frames\frame_0237.jpg
# 🖼️ 저장됨: frames\frame_0238.jpg
# 🖼️ 저장됨: frames\frame_0239.jpg
# 🖼️ 저장됨: frames\frame_0240.jpg
# 🖼️ 저장됨: frames\frame_0241.jpg
# 🖼️ 저장됨: frames\frame_0242.jpg
# 🖼️ 저장됨: frames\frame_0243.jpg
# 🖼️ 저장됨: frames\frame_0244.jpg
# 🖼️ 저장됨: frames\frame_0245.jpg
# 🖼️ 저장됨: frames\frame_0246.jpg
# 🖼️ 저장됨: frames\frame_0247.jpg
# 🖼️ 저장됨: frames\frame_0248.jpg
# 🖼️ 저장됨: frames\frame_0249.jpg
# 🖼️ 저장됨: frames\frame_0250.jpg
# 🖼️ 저장됨: frames\frame_0251.jpg
# 🖼️ 저장됨: frames\frame_0252.jpg
# 🖼️ 저장됨: frames\frame_0253.jpg
# 🖼️ 저장됨: frames\frame_0254.jpg
# 🖼️ 저장됨: frames\frame_0255.jpg
# 🖼️ 저장됨: frames\frame_0256.jpg
# 🖼️ 저장됨: frames\frame_0257.jpg
# 🖼️ 저장됨: frames\frame_0258.jpg
# 🖼️ 저장됨: frames\frame_0259.jpg
# 🖼️ 저장됨: frames\frame_0260.jpg
# 🖼️ 저장됨: frames\frame_0261.jpg
# 🖼️ 저장됨: frames\frame_0262.jpg
# 🖼️ 저장됨: frames\frame_0263.jpg
# 🖼️ 저장됨: frames\frame_0264.jpg
# 🖼️ 저장됨: frames\frame_0265.jpg
# 🖼️ 저장됨: frames\frame_0266.jpg
# 🖼️ 저장됨: frames\frame_0267.jpg
# 🖼️ 저장됨: frames\frame_0268.jpg
# 🖼️ 저장됨: frames\frame_0269.jpg
# 🖼️ 저장됨: frames\frame_0270.jpg
# 🖼️ 저장됨: frames\frame_0271.jpg
# 🖼️ 저장됨: frames\frame_0272.jpg
# 🖼️ 저장됨: frames\frame_0273.jpg
# 🖼️ 저장됨: frames\frame_0274.jpg
# 🖼️ 저장됨: frames\frame_0275.jpg
# 🖼️ 저장됨: frames\frame_0276.jpg
# 🖼️ 저장됨: frames\frame_0277.jpg
# 🖼️ 저장됨: frames\frame_0278.jpg
# 🖼️ 저장됨: frames\frame_0279.jpg
# 🖼️ 저장됨: frames\frame_0280.jpg
# 🖼️ 저장됨: frames\frame_0281.jpg
# ✅ 총 282개의 프레임이 추출되었습니다.
# ✅ 프레임 추출 완료: frames

# %%
### ✅ 3. 딥페이크 예측 (GradCAM 사용 여부 포함)
def run_deepfake_prediction(input_folder, output_file="results/deepfake_results.json", batch_size=16, use_gradcam=False):
    print(f"🤖 딥페이크 예측 중... (GradCAM: {use_gradcam})")
    process_all_frames(input_folder, output_file, batch_size, use_gradcam)
    print(f"✅ 예측 완료: {output_file}")

# 사용 예시
output_json = "results/deepfake_results.json"
run_deepfake_prediction(frames_folder, output_json, batch_size=16, use_gradcam=False)
# Out:
# 🤖 딥페이크 예측 중... (GradCAM: False)
# 🔍 Processing: 100%|██████████| 18/18 [00:03<00:00,  5.75it/s]
# ✅ 예측 결과 저장 완료: results/deepfake_results.json
# ✅ 예측 완료: results/deepfake_results.json

# %%
### ✅ 4. 결과 확인 및 GradCAM 시각화
def display_prediction_results(output_json, show_gradcam=False):
    import json
    import os

    with open(output_json, "r") as file:
        data = json.load(file)

    for frame, result in data.items():
        # ✅ 수정: 확률 추출 방식 변경
        prob = result if isinstance(result, float) else result.get("probability", 0.0)

        print(f"📊 {frame}: 딥페이크 확률 = {prob*100:.2f}%")

        if show_gradcam:
            gradcam_path = result.get("gradcam_path")
            if gradcam_path and os.path.exists(gradcam_path):
                from PIL import Image
                import matplotlib.pyplot as plt

                img = Image.open(gradcam_path)
                plt.imshow(img)
                plt.title(f"GradCAM for {frame}")
                plt.axis('off')
                plt.show()


# 사용 예시
display_prediction_results(output_json, show_gradcam=False)
# Out:
# 📊 frame_0000.jpg: 딥페이크 확률 = 1.18%
# 📊 frame_0001.jpg: 딥페이크 확률 = 1.97%
# 📊 frame_0002.jpg: 딥페이크 확률 = 0.90%
# 📊 frame_0003.jpg: 딥페이크 확률 = 0.63%
# 📊 frame_0004.jpg: 딥페이크 확률 = 0.63%
# 📊 frame_0005.jpg: 딥페이크 확률 = 0.84%
# 📊 frame_0006.jpg: 딥페이크 확률 = 0.71%
# 📊 frame_0007.jpg: 딥페이크 확률 = 0.64%
# 📊 frame_0008.jpg: 딥페이크 확률 = 0.81%
# 📊 frame_0009.jpg: 딥페이크 확률 = 0.99%
# 📊 frame_0010.jpg: 딥페이크 확률 = 0.41%
# 📊 frame_0011.jpg: 딥페이크 확률 = 0.48%
# 📊 frame_0012.jpg: 딥페이크 확률 = 0.27%
# 📊 frame_0013.jpg: 딥페이크 확률 = 0.34%
# 📊 frame_0014.jpg: 딥페이크 확률 = 0.21%
# 📊 frame_0015.jpg: 딥페이크 확률 = 0.12%
# 📊 frame_0016.jpg: 딥페이크 확률 = 0.15%
# 📊 frame_0017.jpg: 딥페이크 확률 = 0.39%
# 📊 frame_0018.jpg: 딥페이크 확률 = 0.52%
# 📊 frame_0019.jpg: 딥페이크 확률 = 0.47%
# 📊 frame_0020.jpg: 딥페이크 확률 = 0.43%
# 📊 frame_0021.jpg: 딥페이크 확률 = 0.33%
# 📊 frame_0022.jpg: 딥페이크 확률 = 0.70%
# 📊 frame_0023.jpg: 딥페이크 확률 = 0.61%
# 📊 frame_0024.jpg: 딥페이크 확률 = 0.27%
# 📊 frame_0025.jpg: 딥페이크 확률 = 0.34%
# 📊 frame_0026.jpg: 딥페이크 확률 = 0.32%
# 📊 frame_0027.jpg: 딥페이크 확률 = 0.35%
# 📊 frame_0028.jpg: 딥페이크 확률 = 0.25%
# 📊 frame_0029.jpg: 딥페이크 확률 = 0.33%
# 📊 frame_0030.jpg: 딥페이크 확률 = 0.31%
# 📊 frame_0031.jpg: 딥페이크 확률 = 0.41%
# 📊 frame_0032.jpg: 딥페이크 확률 = 0.40%
# 📊 frame_0033.jpg: 딥페이크 확률 = 0.45%
# 📊 frame_0034.jpg: 딥페이크 확률 = 0.32%
# 📊 frame_0035.jpg: 딥페이크 확률 = 0.44%
# 📊 frame_0036.jpg: 딥페이크 확률 = 0.43%
# 📊 frame_0037.jpg: 딥페이크 확률 = 0.44%
# 📊 frame_0038.jpg: 딥페이크 확률 = 0.42%
# 📊 frame_0039.jpg: 딥페이크 확률 = 0.52%
# 📊 frame_0040.jpg: 딥페이크 확률 = 0.36%
# 📊 frame_0041.jpg: 딥페이크 확률 = 0.52%
# 📊 frame_0042.jpg: 딥페이크 확률 = 0.46%
# 📊 frame_0043.jpg: 딥페이크 확률 = 0.44%
# 📊 frame_0044.jpg: 딥페이크 확률 = 0.50%
# 📊 frame_0045.jpg: 딥페이크 확률 = 0.29%
# 📊 frame_0046.jpg: 딥페이크 확률 = 0.10%
# 📊 frame_0047.jpg: 딥페이크 확률 = 0.14%
# 📊 frame_0048.jpg: 딥페이크 확률 = 0.06%
# 📊 frame_0049.jpg: 딥페이크 확률 = 0.21%
# 📊 frame_0050.jpg: 딥페이크 확률 = 0.31%
# 📊 frame_0051.jpg: 딥페이크 확률 = 0.24%
# 📊 frame_0052.jpg: 딥페이크 확률 = 1.61%
# 📊 frame_0053.jpg: 딥페이크 확률 = 1.56%
# 📊 frame_0054.jpg: 딥페이크 확률 = 0.77%
# 📊 frame_0055.jpg: 딥페이크 확률 = 0.46%
# 📊 frame_0056.jpg: 딥페이크 확률 = 0.28%
# 📊 frame_0057.jpg: 딥페이크 확률 = 0.28%
# 📊 frame_0058.jpg: 딥페이크 확률 = 0.20%
# 📊 frame_0059.jpg: 딥페이크 확률 = 0.11%
# 📊 frame_0060.jpg: 딥페이크 확률 = 0.16%
# 📊 frame_0061.jpg: 딥페이크 확률 = 0.22%
# 📊 frame_0062.jpg: 딥페이크 확률 = 0.17%
# 📊 frame_0063.jpg: 딥페이크 확률 = 0.27%
# 📊 frame_0064.jpg: 딥페이크 확률 = 0.23%
# 📊 frame_0065.jpg: 딥페이크 확률 = 0.15%
# 📊 frame_0066.jpg: 딥페이크 확률 = 0.16%
# 📊 frame_0067.jpg: 딥페이크 확률 = 0.12%
# 📊 frame_0068.jpg: 딥페이크 확률 = 0.09%
# 📊 frame_0069.jpg: 딥페이크 확률 = 0.07%
# 📊 frame_0070.jpg: 딥페이크 확률 = 0.08%
# 📊 frame_0071.jpg: 딥페이크 확률 = 0.08%
# 📊 frame_0072.jpg: 딥페이크 확률 = 0.04%
# 📊 frame_0073.jpg: 딥페이크 확률 = 0.05%
# 📊 frame_0074.jpg: 딥페이크 확률 = 0.05%
# 📊 frame_0075.jpg: 딥페이크 확률 = 0.07%
# 📊 frame_0076.jpg: 딥페이크 확률 = 0.07%
# 📊 frame_0077.jpg: 딥페이크 확률 = 0.07%
# 📊 frame_0078.jpg: 딥페이크 확률 = 0.07%
# 📊 frame_0079.jpg: 딥페이크 확률 = 0.10%
# 📊 frame_0080.jpg: 딥페이크 확률 = 0.22%
# 📊 frame_0081.jpg: 딥페이크 확률 = 0.09%
# 📊 frame_0082.jpg: 딥페이크 확률 = 0.13%
# 📊 frame_0083.jpg: 딥페이크 확률 = 0.15%
# 📊 frame_0084.jpg: 딥페이크 확률 = 0.11%
# 📊 frame_0085.jpg: 딥페이크 확률 = 0.11%
# 📊 frame_0086.jpg: 딥페이크 확률 = 0.18%
# 📊 frame_0087.jpg: 딥페이크 확률 = 0.16%
# 📊 frame_0088.jpg: 딥페이크 확률 = 0.16%
# 📊 frame_0089.jpg: 딥페이크 확률 = 0.17%
# 📊 frame_0090.jpg: 딥페이크 확률 = 0.16%
# 📊 frame_0091.jpg: 딥페이크 확률 = 0.16%
# 📊 frame_0092.jpg: 딥페이크 확률 = 0.17%
# 📊 frame_0093.jpg: 딥페이크 확률 = 0.17%
# 📊 frame_0094.jpg: 딥페이크 확률 = 0.44%
# 📊 frame_0095.jpg: 딥페이크 확률 = 0.28%
# 📊 frame_0096.jpg: 딥페이크 확률 = 0.52%
# 📊 frame_0097.jpg: 딥페이크 확률 = 0.55%
# 📊 frame_0098.jpg: 딥페이크 확률 = 0.67%
# 📊 frame_0099.jpg: 딥페이크 확률 = 0.24%
# 📊 frame_0100.jpg: 딥페이크 확률 = 0.48%
# 📊 frame_0101.jpg: 딥페이크 확률 = 0.55%
# 📊 frame_0102.jpg: 딥페이크 확률 = 0.70%
# 📊 frame_0103.jpg: 딥페이크 확률 = 3.27%
# 📊 frame_0104.jpg: 딥페이크 확률 = 2.29%
# 📊 frame_0105.jpg: 딥페이크 확률 = 2.46%
# 📊 frame_0106.jpg: 딥페이크 확률 = 1.92%
# 📊 frame_0107.jpg: 딥페이크 확률 = 1.31%
# 📊 frame_0108.jpg: 딥페이크 확률 = 1.07%
# 📊 frame_0109.jpg: 딥페이크 확률 = 0.72%
# 📊 frame_0110.jpg: 딥페이크 확률 = 0.88%
# 📊 frame_0111.jpg: 딥페이크 확률 = 0.64%
# 📊 frame_0112.jpg: 딥페이크 확률 = 0.48%
# 📊 frame_0113.jpg: 딥페이크 확률 = 0.36%
# 📊 frame_0114.jpg: 딥페이크 확률 = 0.56%
# 📊 frame_0115.jpg: 딥페이크 확률 = 0.84%
# 📊 frame_0116.jpg: 딥페이크 확률 = 1.08%
# 📊 frame_0117.jpg: 딥페이크 확률 = 1.16%
# 📊 frame_0118.jpg: 딥페이크 확률 = 0.86%
# 📊 frame_0119.jpg: 딥페이크 확률 = 0.57%
# 📊 frame_0120.jpg: 딥페이크 확률 = 0.38%
# 📊 frame_0121.jpg: 딥페이크 확률 = 0.47%
# 📊 frame_0122.jpg: 딥페이크 확률 = 0.39%
# 📊 frame_0123.jpg: 딥페이크 확률 = 0.32%
# 📊 frame_0124.jpg: 딥페이크 확률 = 0.26%
# 📊 frame_0125.jpg: 딥페이크 확률 = 0.47%
# 📊 frame_0126.jpg: 딥페이크 확률 = 0.47%
# 📊 frame_0127.jpg: 딥페이크 확률 = 0.11%
# 📊 frame_0128.jpg: 딥페이크 확률 = 0.08%
# 📊 frame_0129.jpg: 딥페이크 확률 = 0.14%
# 📊 frame_0130.jpg: 딥페이크 확률 = 0.15%
# 📊 frame_0131.jpg: 딥페이크 확률 = 0.21%
# 📊 frame_0132.jpg: 딥페이크 확률 = 0.31%
# 📊 frame_0133.jpg: 딥페이크 확률 = 0.44%
# 📊 frame_0134.jpg: 딥페이크 확률 = 0.45%
# 📊 frame_0135.jpg: 딥페이크 확률 = 0.28%
# 📊 frame_0136.jpg: 딥페이크 확률 = 0.44%
# 📊 frame_0137.jpg: 딥페이크 확률 = 0.41%
# 📊 frame_0138.jpg: 딥페이크 확률 = 0.17%
# 📊 frame_0139.jpg: 딥페이크 확률 = 0.25%
# 📊 frame_0140.jpg: 딥페이크 확률 = 0.20%
# 📊 frame_0141.jpg: 딥페이크 확률 = 0.11%
# 📊 frame_0142.jpg: 딥페이크 확률 = 0.36%
# 📊 frame_0143.jpg: 딥페이크 확률 = 0.22%
# 📊 frame_0144.jpg: 딥페이크 확률 = 1.10%
# 📊 frame_0145.jpg: 딥페이크 확률 = 0.82%
# 📊 frame_0146.jpg: 딥페이크 확률 = 0.54%
# 📊 frame_0147.jpg: 딥페이크 확률 = 1.30%
# 📊 frame_0148.jpg: 딥페이크 확률 = 2.51%
# 📊 frame_0149.jpg: 딥페이크 확률 = 2.53%
# 📊 frame_0150.jpg: 딥페이크 확률 = 5.08%
# 📊 frame_0151.jpg: 딥페이크 확률 = 5.13%
# 📊 frame_0152.jpg: 딥페이크 확률 = 3.99%
# 📊 frame_0153.jpg: 딥페이크 확률 = 3.74%
# 📊 frame_0154.jpg: 딥페이크 확률 = 5.55%
# 📊 frame_0155.jpg: 딥페이크 확률 = 4.30%
# 📊 frame_0156.jpg: 딥페이크 확률 = 8.03%
# 📊 frame_0157.jpg: 딥페이크 확률 = 3.36%
# 📊 frame_0158.jpg: 딥페이크 확률 = 3.15%
# 📊 frame_0159.jpg: 딥페이크 확률 = 3.01%
# 📊 frame_0160.jpg: 딥페이크 확률 = 2.62%
# 📊 frame_0161.jpg: 딥페이크 확률 = 1.67%
# 📊 frame_0162.jpg: 딥페이크 확률 = 2.58%
# 📊 frame_0163.jpg: 딥페이크 확률 = 1.56%
# 📊 frame_0164.jpg: 딥페이크 확률 = 2.29%
# 📊 frame_0165.jpg: 딥페이크 확률 = 2.08%
# 📊 frame_0166.jpg: 딥페이크 확률 = 2.77%
# 📊 frame_0167.jpg: 딥페이크 확률 = 1.93%
# 📊 frame_0168.jpg: 딥페이크 확률 = 0.83%
# 📊 frame_0169.jpg: 딥페이크 확률 = 1.08%
# 📊 frame_0170.jpg: 딥페이크 확률 = 1.89%
# 📊 frame_0171.jpg: 딥페이크 확률 = 0.88%
# 📊 frame_0172.jpg: 딥페이크 확률 = 0.44%
# 📊 frame_0173.jpg: 딥페이크 확률 = 1.43%
# 📊 frame_0174.jpg: 딥페이크 확률 = 1.39%
# 📊 frame_0175.jpg: 딥페이크 확률 = 0.92%
# 📊 frame_0176.jpg: 딥페이크 확률 = 0.56%
# 📊 frame_0177.jpg: 딥페이크 확률 = 0.44%
# 📊 frame_0178.jpg: 딥페이크 확률 = 3.65%
# 📊 frame_0179.jpg: 딥페이크 확률 = 4.72%
# 📊 frame_0180.jpg: 딥페이크 확률 = 1.42%
# 📊 frame_0181.jpg: 딥페이크 확률 = 0.42%
# 📊 frame_0182.jpg: 딥페이크 확률 = 0.32%
# 📊 frame_0183.jpg: 딥페이크 확률 = 0.39%
# 📊 frame_0184.jpg: 딥페이크 확률 = 0.69%
# 📊 frame_0185.jpg: 딥페이크 확률 = 0.62%
# 📊 frame_0186.jpg: 딥페이크 확률 = 0.64%
# 📊 frame_0187.jpg: 딥페이크 확률 = 0.63%
# 📊 frame_0188.jpg: 딥페이크 확률 = 0.90%
# 📊 frame_0189.jpg: 딥페이크 확률 = 2.93%
# 📊 frame_0190.jpg: 딥페이크 확률 = 3.90%
# 📊 frame_0191.jpg: 딥페이크 확률 = 3.55%
# 📊 frame_0192.jpg: 딥페이크 확률 = 0.76%
# 📊 frame_0193.jpg: 딥페이크 확률 = 0.85%
# 📊 frame_0194.jpg: 딥페이크 확률 = 1.34%
# 📊 frame_0195.jpg: 딥페이크 확률 = 2.60%
# 📊 frame_0196.jpg: 딥페이크 확률 = 2.83%
# 📊 frame_0197.jpg: 딥페이크 확률 = 1.84%
# 📊 frame_0198.jpg: 딥페이크 확률 = 1.84%
# 📊 frame_0199.jpg: 딥페이크 확률 = 2.20%
# 📊 frame_0200.jpg: 딥페이크 확률 = 8.93%
# 📊 frame_0201.jpg: 딥페이크 확률 = 4.23%
# 📊 frame_0202.jpg: 딥페이크 확률 = 6.33%
# 📊 frame_0203.jpg: 딥페이크 확률 = 9.86%
# 📊 frame_0204.jpg: 딥페이크 확률 = 11.15%
# 📊 frame_0205.jpg: 딥페이크 확률 = 11.90%
# 📊 frame_0206.jpg: 딥페이크 확률 = 7.50%
# 📊 frame_0207.jpg: 딥페이크 확률 = 15.23%
# 📊 frame_0208.jpg: 딥페이크 확률 = 15.41%
# 📊 frame_0209.jpg: 딥페이크 확률 = 11.69%
# 📊 frame_0210.jpg: 딥페이크 확률 = 10.02%
# 📊 frame_0211.jpg: 딥페이크 확률 = 5.42%
# 📊 frame_0212.jpg: 딥페이크 확률 = 5.10%
# 📊 frame_0213.jpg: 딥페이크 확률 = 5.03%
# 📊 frame_0214.jpg: 딥페이크 확률 = 5.95%
# 📊 frame_0215.jpg: 딥페이크 확률 = 8.87%
# 📊 frame_0216.jpg: 딥페이크 확률 = 3.49%
# 📊 frame_0217.jpg: 딥페이크 확률 = 4.25%
# 📊 frame_0218.jpg: 딥페이크 확률 = 5.24%
# 📊 frame_0219.jpg: 딥페이크 확률 = 4.88%
# 📊 frame_0220.jpg: 딥페이크 확률 = 6.40%
# 📊 frame_0221.jpg: 딥페이크 확률 = 6.24%
# 📊 frame_0222.jpg: 딥페이크 확률 = 2.43%
# 📊 frame_0223.jpg: 딥페이크 확률 = 1.66%
# 📊 frame_0224.jpg: 딥페이크 확률 = 0.90%
# 📊 frame_0225.jpg: 딥페이크 확률 = 2.23%
# 📊 frame_0226.jpg: 딥페이크 확률 = 1.59%
# 📊 frame_0227.jpg: 딥페이크 확률 = 0.50%
# 📊 frame_0228.jpg: 딥페이크 확률 = 3.77%
# 📊 frame_0229.jpg: 딥페이크 확률 = 3.50%
# 📊 frame_0230.jpg: 딥페이크 확률 = 1.91%
# 📊 frame_0231.jpg: 딥페이크 확률 = 1.14%
# 📊 frame_0232.jpg: 딥페이크 확률 = 1.98%
# 📊 frame_0233.jpg: 딥페이크 확률 = 3.55%
# 📊 frame_0234.jpg: 딥페이크 확률 = 4.79%
# 📊 frame_0235.jpg: 딥페이크 확률 = 4.02%
# 📊 frame_0236.jpg: 딥페이크 확률 = 5.49%
# 📊 frame_0237.jpg: 딥페이크 확률 = 4.85%
# 📊 frame_0238.jpg: 딥페이크 확률 = 4.07%
# 📊 frame_0239.jpg: 딥페이크 확률 = 2.21%
# 📊 frame_0240.jpg: 딥페이크 확률 = 1.03%
# 📊 frame_0241.jpg: 딥페이크 확률 = 2.05%
# 📊 frame_0242.jpg: 딥페이크 확률 = 1.56%
# 📊 frame_0243.jpg: 딥페이크 확률 = 1.37%
# 📊 frame_0244.jpg: 딥페이크 확률 = 1.35%
# 📊 frame_0245.jpg: 딥페이크 확률 = 1.29%
# 📊 frame_0246.jpg: 딥페이크 확률 = 1.87%
# 📊 frame_0247.jpg: 딥페이크 확률 = 1.50%
# 📊 frame_0248.jpg: 딥페이크 확률 = 2.35%
# 📊 frame_0249.jpg: 딥페이크 확률 = 3.11%
# 📊 frame_0250.jpg: 딥페이크 확률 = 1.90%
# 📊 frame_0251.jpg: 딥페이크 확률 = 1.16%
# 📊 frame_0252.jpg: 딥페이크 확률 = 1.02%
# 📊 frame_0253.jpg: 딥페이크 확률 = 0.89%
# 📊 frame_0254.jpg: 딥페이크 확률 = 1.63%
# 📊 frame_0255.jpg: 딥페이크 확률 = 2.24%
# 📊 frame_0256.jpg: 딥페이크 확률 = 1.63%
# 📊 frame_0257.jpg: 딥페이크 확률 = 0.73%
# 📊 frame_0258.jpg: 딥페이크 확률 = 0.66%
# 📊 frame_0259.jpg: 딥페이크 확률 = 1.01%
# 📊 frame_0260.jpg: 딥페이크 확률 = 0.53%
# 📊 frame_0261.jpg: 딥페이크 확률 = 0.84%
# 📊 frame_0262.jpg: 딥페이크 확률 = 0.61%
# 📊 frame_0263.jpg: 딥페이크 확률 = 0.89%
# 📊 frame_0264.jpg: 딥페이크 확률 = 0.65%
# 📊 frame_0265.jpg: 딥페이크 확률 = 0.27%
# 📊 frame_0266.jpg: 딥페이크 확률 = 0.43%
# 📊 frame_0267.jpg: 딥페이크 확률 = 1.27%
# 📊 frame_0268.jpg: 딥페이크 확률 = 0.77%
# 📊 frame_0269.jpg: 딥페이크 확률 = 0.42%
# 📊 frame_0270.jpg: 딥페이크 확률 = 0.28%
# 📊 frame_0271.jpg: 딥페이크 확률 = 0.25%
# 📊 frame_0272.jpg: 딥페이크 확률 = 0.65%
# 📊 frame_0273.jpg: 딥페이크 확률 = 0.27%
# 📊 frame_0274.jpg: 딥페이크 확률 = 0.28%
# 📊 frame_0275.jpg: 딥페이크 확률 = 0.26%
# 📊 frame_0276.jpg: 딥페이크 확률 = 0.16%
# 📊 frame_0277.jpg: 딥페이크 확률 = 0.10%
# 📊 frame_0278.jpg: 딥페이크 확률 = 0.08%
# 📊 frame_0279.jpg: 딥페이크 확률 = 0.09%
# 📊 frame_0280.jpg: 딥페이크 확률 = 0.08%
# 📊 frame_0281.jpg: 딥페이크 확률 = 0.24%
